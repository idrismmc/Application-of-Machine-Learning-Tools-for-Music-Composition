# %%
from keras.models import load_model
from keras.callbacks import ModelCheckpoint
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from custom import read_midi, read_data, prepare_data, get_transition_matrix, generate_stochastic_music, pick_chord_probs
from custom import generate_music, convert_to_midi, cnn, lstm
# Out:
# Using TensorFlow backend.

# %% [markdown]
# # First-order Markov Chain

# %%
path = 'midi'
notes_, n_vocab, notes_dictionary = read_data(path)
transformed_notes = []
for i in notes_:
    transformed_notes.append(notes_dictionary[i])
    
trans = get_transition_matrix(transformed_notes,n_vocab) 

output_dir_mc = 'Markov chain'
start = np.random.choice(transformed_notes)
music = generate_stochastic_music(trans,start,notes_dictionary)
convert_to_midi(music,output_dir_mc)
# Out:
# Parsing midi/1.mid
# 252
# Parsing midi/10.mid
# 282
# Parsing midi/11.mid
# 236
# Parsing midi/12.mid
# 210
# Parsing midi/13.mid
# 76
# Parsing midi/14.mid
# 198
# Parsing midi/15.mid
# 201
# Parsing midi/16.mid
# 204
# Parsing midi/17.mid
# 119
# Parsing midi/18.mid
# 242
# Parsing midi/19.mid
# 255
# Parsing midi/2.mid
# 74
# Parsing midi/20.mid
# 216
# Parsing midi/21.mid
# 170
# Parsing midi/22.mid
# 173
# Parsing midi/23.mid
# 183
# Parsing midi/24.mid
# 114
# Parsing midi/25.mid
# 121
# Parsing midi/26.mid
# 119
# Parsing midi/3.mid
# 274
# Parsing midi/4.mid
# 184
# Parsing midi/5.mid
# 121
# Parsing midi/6.mid
# 183
# Parsing midi/7.mid
# 141
# Parsing midi/8.mid
# 180
# Parsing midi/9.mid
# 290
# unique chords 54

# %% [markdown]
# ### Setting lookback parameter and preparing input sequences for the deep learning models

# %%
# path = 'final dataset/'
# notes_, n_vocab, notes_dictionary = read_data(path)
lookback = 30
batch_size =32
x, y = prepare_data(notes_, notes_dictionary, lookback)
x_tr, x_val, y_tr, y_val = train_test_split(x, y, test_size=0.2, random_state=0)

# %% [markdown]
# ### Training LSTM model

# %%
model = lstm(n_vocab,lookback)
mc=ModelCheckpoint('lstm_best_model.h5', monitor='loss', mode='min', save_best_only=True,verbose=1)
lstm_history = model.fit(x_tr,y_tr,validation_data=(x_val,y_val),batch_size=batch_size,epochs=50,verbose=1, callbacks=[mc])
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm_1 (LSTM)                (None, 30, 128)           66560
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 30, 128)           0
# _________________________________________________________________
# lstm_2 (LSTM)                (None, 128)               131584
# _________________________________________________________________
# activation_1 (Activation)    (None, 128)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 54)                6966
# _________________________________________________________________
# activation_2 (Activation)    (None, 54)                0
# =================================================================
# Total params: 205,110
# Trainable params: 205,110
# Non-trainable params: 0
# _________________________________________________________________
# Train on 3829 samples, validate on 958 samples
# Epoch 1/50
# 3829/3829 [==============================] - 6s 2ms/step - loss: 3.3318 - accuracy: 0.0752 - val_loss: 3.2499 - val_accuracy: 0.0678
#
# Epoch 00001: loss improved from inf to 3.33177, saving model to lstm_best_model.h5
# Epoch 2/50
# 3829/3829 [==============================] - 6s 2ms/step - loss: 3.2515 - accuracy: 0.0836 - val_loss: 3.2491 - val_accuracy: 0.1044
#
# Epoch 00002: loss improved from 3.33177 to 3.25155, saving model to lstm_best_model.h5
# Epoch 3/50
# 3829/3829 [==============================] - 5s 1ms/step - loss: 3.2474 - accuracy: 0.0849 - val_loss: 3.2471 - val_accuracy: 0.1044
#
# Epoch 00003: loss improved from 3.25155 to 3.24743, saving model to lstm_best_model.h5
# Epoch 4/50
# 3829/3829 [==============================] - 6s 1ms/step - loss: 3.2467 - accuracy: 0.0914 - val_loss: 3.2389 - val_accuracy: 0.1044
#
# Epoch 00004: loss improved from 3.24743 to 3.24667, saving model to lstm_best_model.h5
# Epoch 5/50
# 3829/3829 [==============================] - 6s 1ms/step - loss: 3.2419 - accuracy: 0.0898 - val_loss: 3.2503 - val_accuracy: 0.0605
#
# Epoch 00005: loss improved from 3.24667 to 3.24190, saving model to lstm_best_model.h5
# Epoch 6/50
# 3829/3829 [==============================] - 6s 1ms/step - loss: 3.2452 - accuracy: 0.0831 - val_loss: 3.2425 - val_accuracy: 0.0793
#
# Epoch 00006: loss did not improve from 3.24190
# Epoch 7/50
# 3829/3829 [==============================] - 6s 1ms/step - loss: 3.2429 - accuracy: 0.0914 - val_loss: 3.2374 - val_accuracy: 0.1044
#
# Epoch 00007: loss did not improve from 3.24190
# Epoch 8/50
# 3829/3829 [==============================] - 6s 1ms/step - loss: 3.2419 - accuracy: 0.0825 - val_loss: 3.2472 - val_accuracy: 0.1044
#
# Epoch 00008: loss improved from 3.24190 to 3.24186, saving model to lstm_best_model.h5
# Epoch 9/50
# 3829/3829 [==============================] - 6s 1ms/step - loss: 3.2237 - accuracy: 0.0885 - val_loss: 3.1729 - val_accuracy: 0.1106
#
# Epoch 00009: loss improved from 3.24186 to 3.22372, saving model to lstm_best_model.h5
# Epoch 10/50
# 3829/3829 [==============================] - 6s 2ms/step - loss: 3.1539 - accuracy: 0.1149 - val_loss: 3.1230 - val_accuracy: 0.1336
#
# Epoch 00010: loss improved from 3.22372 to 3.15387, saving model to lstm_best_model.h5
# Epoch 11/50
# 3829/3829 [==============================] - 6s 1ms/step - loss: 3.0942 - accuracy: 0.1233 - val_loss: 3.1047 - val_accuracy: 0.1378
#
# Epoch 00011: loss improved from 3.15387 to 3.09424, saving model to lstm_best_model.h5
# Epoch 12/50
# 3829/3829 [==============================] - 6s 1ms/step - loss: 3.0584 - accuracy: 0.1303 - val_loss: 3.0833 - val_accuracy: 0.1305
#
# Epoch 00012: loss improved from 3.09424 to 3.05837, saving model to lstm_best_model.h5
# Epoch 13/50
# 3829/3829 [==============================] - 6s 2ms/step - loss: 3.0434 - accuracy: 0.1321 - val_loss: 3.0664 - val_accuracy: 0.1200
#
# Epoch 00013: loss improved from 3.05837 to 3.04341, saving model to lstm_best_model.h5
# Epoch 14/50
# 3829/3829 [==============================] - 6s 2ms/step - loss: 3.0171 - accuracy: 0.1369 - val_loss: 3.1074 - val_accuracy: 0.1326
#
# Epoch 00014: loss improved from 3.04341 to 3.01715, saving model to lstm_best_model.h5
# Epoch 15/50
# 3829/3829 [==============================] - 6s 2ms/step - loss: 3.0128 - accuracy: 0.1423 - val_loss: 3.0271 - val_accuracy: 0.1399
#
# Epoch 00015: loss improved from 3.01715 to 3.01282, saving model to lstm_best_model.h5
# Epoch 16/50
# 3829/3829 [==============================] - 6s 2ms/step - loss: 2.9930 - accuracy: 0.1361 - val_loss: 3.0324 - val_accuracy: 0.1367
#
# Epoch 00016: loss improved from 3.01282 to 2.99300, saving model to lstm_best_model.h5
# Epoch 17/50
# 1472/3829 [==========>...................] - ETA: 3s - loss: 2.9576 - accuracy: 0.1406

# %% [markdown]
# ### Training 1DCNN model

# %%
model = cnn(n_vocab,lookback)
mc=ModelCheckpoint('cnn_best_model.h5', monitor='loss', mode='min', save_best_only=True,verbose=1)
cnn_history = model.fit(x_tr,y_tr,validation_data=(x_val,y_val),batch_size=batch_size,epochs=50,verbose=1, callbacks=[mc])
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv1d_1 (Conv1D)            (None, 30, 32)            128
# _________________________________________________________________
# max_pooling1d_1 (MaxPooling1 (None, 15, 32)            0
# _________________________________________________________________
# conv1d_2 (Conv1D)            (None, 15, 64)            6208
# _________________________________________________________________
# max_pooling1d_2 (MaxPooling1 (None, 7, 64)             0
# _________________________________________________________________
# conv1d_3 (Conv1D)            (None, 7, 128)            24704
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 7, 128)            0
# _________________________________________________________________
# max_pooling1d_3 (MaxPooling1 (None, 3, 128)            0
# _________________________________________________________________
# conv1d_4 (Conv1D)            (None, 3, 256)            98560
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 3, 256)            0
# _________________________________________________________________
# max_pooling1d_4 (MaxPooling1 (None, 1, 256)            0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 256)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 54)                13878
# =================================================================
# Total params: 143,478
# Trainable params: 143,478
# Non-trainable params: 0
# _________________________________________________________________
# Train on 3829 samples, validate on 958 samples
# Epoch 1/50
# 3829/3829 [==============================] - 1s 270us/step - loss: 3.3726 - accuracy: 0.0755 - val_loss: 3.2163 - val_accuracy: 0.1054
#
# Epoch 00001: loss improved from inf to 3.37255, saving model to cnn_best_model.h5
# Epoch 2/50
# 3829/3829 [==============================] - 1s 151us/step - loss: 3.1598 - accuracy: 0.0945 - val_loss: 3.1266 - val_accuracy: 0.1242
#
# Epoch 00002: loss improved from 3.37255 to 3.15977, saving model to cnn_best_model.h5
# Epoch 3/50
# 3829/3829 [==============================] - 1s 154us/step - loss: 3.0922 - accuracy: 0.1060 - val_loss: 3.1272 - val_accuracy: 0.0835
#
# Epoch 00003: loss improved from 3.15977 to 3.09222, saving model to cnn_best_model.h5
# Epoch 4/50
# 3829/3829 [==============================] - 1s 153us/step - loss: 3.0462 - accuracy: 0.1157 - val_loss: 3.0551 - val_accuracy: 0.1023
#
# Epoch 00004: loss improved from 3.09222 to 3.04618, saving model to cnn_best_model.h5
# Epoch 5/50
# 3829/3829 [==============================] - 1s 155us/step - loss: 3.0061 - accuracy: 0.1227 - val_loss: 2.9980 - val_accuracy: 0.1232
#
# Epoch 00005: loss improved from 3.04618 to 3.00613, saving model to cnn_best_model.h5
# Epoch 6/50
# 3829/3829 [==============================] - 1s 155us/step - loss: 2.9563 - accuracy: 0.1316 - val_loss: 2.9838 - val_accuracy: 0.1169
#
# Epoch 00006: loss improved from 3.00613 to 2.95631, saving model to cnn_best_model.h5
# Epoch 7/50
# 3829/3829 [==============================] - 1s 151us/step - loss: 2.9134 - accuracy: 0.1408 - val_loss: 2.9229 - val_accuracy: 0.1232
#
# Epoch 00007: loss improved from 2.95631 to 2.91343, saving model to cnn_best_model.h5
# Epoch 8/50
# 3829/3829 [==============================] - 1s 155us/step - loss: 2.8612 - accuracy: 0.1541 - val_loss: 2.8844 - val_accuracy: 0.1806
#
# Epoch 00008: loss improved from 2.91343 to 2.86119, saving model to cnn_best_model.h5
# Epoch 9/50
# 3829/3829 [==============================] - 1s 156us/step - loss: 2.8103 - accuracy: 0.1685 - val_loss: 2.8770 - val_accuracy: 0.1524
#
# Epoch 00009: loss improved from 2.86119 to 2.81032, saving model to cnn_best_model.h5
# Epoch 10/50
# 3829/3829 [==============================] - 1s 152us/step - loss: 2.7610 - accuracy: 0.1893 - val_loss: 2.8268 - val_accuracy: 0.1858
#
# Epoch 00010: loss improved from 2.81032 to 2.76099, saving model to cnn_best_model.h5
# Epoch 11/50
# 3829/3829 [==============================] - 1s 157us/step - loss: 2.7229 - accuracy: 0.1880 - val_loss: 2.7843 - val_accuracy: 0.1837
#
# Epoch 00011: loss improved from 2.76099 to 2.72285, saving model to cnn_best_model.h5
# Epoch 12/50
# 3829/3829 [==============================] - 1s 185us/step - loss: 2.6891 - accuracy: 0.1964 - val_loss: 2.7699 - val_accuracy: 0.1889
#
# Epoch 00012: loss improved from 2.72285 to 2.68913, saving model to cnn_best_model.h5
# Epoch 13/50
# 3829/3829 [==============================] - 1s 181us/step - loss: 2.6529 - accuracy: 0.1961 - val_loss: 2.7576 - val_accuracy: 0.1743
#
# Epoch 00013: loss improved from 2.68913 to 2.65288, saving model to cnn_best_model.h5
# Epoch 14/50
# 3829/3829 [==============================] - 1s 183us/step - loss: 2.6177 - accuracy: 0.2040 - val_loss: 2.7105 - val_accuracy: 0.2109
#
# Epoch 00014: loss improved from 2.65288 to 2.61774, saving model to cnn_best_model.h5
# Epoch 15/50
# 3829/3829 [==============================] - 1s 175us/step - loss: 2.5809 - accuracy: 0.2126 - val_loss: 2.6928 - val_accuracy: 0.2067
#
# Epoch 00015: loss improved from 2.61774 to 2.58085, saving model to cnn_best_model.h5
# Epoch 16/50
# 3829/3829 [==============================] - 1s 176us/step - loss: 2.5630 - accuracy: 0.2131 - val_loss: 2.6893 - val_accuracy: 0.2244
#
# Epoch 00016: loss improved from 2.58085 to 2.56300, saving model to cnn_best_model.h5
# Epoch 17/50
# 3829/3829 [==============================] - 1s 187us/step - loss: 2.5218 - accuracy: 0.2277 - val_loss: 2.6675 - val_accuracy: 0.2182
#
# Epoch 00017: loss improved from 2.56300 to 2.52184, saving model to cnn_best_model.h5
# Epoch 18/50
# 3829/3829 [==============================] - 1s 146us/step - loss: 2.4994 - accuracy: 0.2212 - val_loss: 2.6336 - val_accuracy: 0.2296
#
# Epoch 00018: loss improved from 2.52184 to 2.49945, saving model to cnn_best_model.h5
# Epoch 19/50
# 3829/3829 [==============================] - 1s 144us/step - loss: 2.4705 - accuracy: 0.2366 - val_loss: 2.6486 - val_accuracy: 0.2077
#
# Epoch 00019: loss improved from 2.49945 to 2.47052, saving model to cnn_best_model.h5
# Epoch 20/50
# 3829/3829 [==============================] - 1s 143us/step - loss: 2.4544 - accuracy: 0.2335 - val_loss: 2.6128 - val_accuracy: 0.2296
#
# Epoch 00020: loss improved from 2.47052 to 2.45440, saving model to cnn_best_model.h5
# Epoch 21/50
# 3829/3829 [==============================] - 1s 143us/step - loss: 2.4131 - accuracy: 0.2476 - val_loss: 2.5896 - val_accuracy: 0.2338
#
# Epoch 00021: loss improved from 2.45440 to 2.41306, saving model to cnn_best_model.h5
# Epoch 22/50
# 3829/3829 [==============================] - 1s 171us/step - loss: 2.4074 - accuracy: 0.2478 - val_loss: 2.5883 - val_accuracy: 0.2182
#
# Epoch 00022: loss improved from 2.41306 to 2.40740, saving model to cnn_best_model.h5
# Epoch 23/50
# 3829/3829 [==============================] - 1s 209us/step - loss: 2.3760 - accuracy: 0.2515 - val_loss: 2.5587 - val_accuracy: 0.2317
#
# Epoch 00023: loss improved from 2.40740 to 2.37600, saving model to cnn_best_model.h5
# Epoch 24/50
# 3829/3829 [==============================] - 1s 144us/step - loss: 2.3592 - accuracy: 0.2565 - val_loss: 2.5793 - val_accuracy: 0.2359
#
# Epoch 00024: loss improved from 2.37600 to 2.35925, saving model to cnn_best_model.h5
# Epoch 25/50
# 3829/3829 [==============================] - 1s 234us/step - loss: 2.3421 - accuracy: 0.2578 - val_loss: 2.5499 - val_accuracy: 0.2401
#
# Epoch 00025: loss improved from 2.35925 to 2.34213, saving model to cnn_best_model.h5
# Epoch 26/50
# 3829/3829 [==============================] - 1s 195us/step - loss: 2.3124 - accuracy: 0.2711 - val_loss: 2.5539 - val_accuracy: 0.2244
#
# Epoch 00026: loss improved from 2.34213 to 2.31245, saving model to cnn_best_model.h5
# Epoch 27/50
# 3829/3829 [==============================] - 1s 184us/step - loss: 2.2813 - accuracy: 0.2761 - val_loss: 2.5435 - val_accuracy: 0.2338
# Epoch 00027: loss improved from 2.31245 to 2.28126, saving model to cnn_best_model.h5
# Epoch 28/50
# 3829/3829 [==============================] - 1s 184us/step - loss: 2.2809 - accuracy: 0.2706 - val_loss: 2.5390 - val_accuracy: 0.2129
#
# Epoch 00028: loss improved from 2.28126 to 2.28093, saving model to cnn_best_model.h5
# Epoch 29/50
# 3829/3829 [==============================] - 1s 172us/step - loss: 2.2644 - accuracy: 0.2766 - val_loss: 2.5103 - val_accuracy: 0.2453
#
# Epoch 00029: loss improved from 2.28093 to 2.26441, saving model to cnn_best_model.h5
# Epoch 30/50
# 3829/3829 [==============================] - 1s 168us/step - loss: 2.2417 - accuracy: 0.2823 - val_loss: 2.5220 - val_accuracy: 0.2338
#
# Epoch 00030: loss improved from 2.26441 to 2.24167, saving model to cnn_best_model.h5
# Epoch 31/50
# 3829/3829 [==============================] - 1s 173us/step - loss: 2.2031 - accuracy: 0.2862 - val_loss: 2.5149 - val_accuracy: 0.2411
#
# Epoch 00031: loss improved from 2.24167 to 2.20314, saving model to cnn_best_model.h5
# Epoch 32/50
# 3829/3829 [==============================] - 1s 147us/step - loss: 2.1958 - accuracy: 0.2915 - val_loss: 2.5076 - val_accuracy: 0.2547
#
# Epoch 00032: loss improved from 2.20314 to 2.19578, saving model to cnn_best_model.h5
# Epoch 33/50
# 3829/3829 [==============================] - 1s 208us/step - loss: 2.1784 - accuracy: 0.2925 - val_loss: 2.5068 - val_accuracy: 0.2192
#
# Epoch 00033: loss improved from 2.19578 to 2.17835, saving model to cnn_best_model.h5
# Epoch 34/50
# 3829/3829 [==============================] - 1s 175us/step - loss: 2.1688 - accuracy: 0.2956 - val_loss: 2.5134 - val_accuracy: 0.2255
#
# Epoch 00034: loss improved from 2.17835 to 2.16879, saving model to cnn_best_model.h5
# Epoch 35/50
# 3829/3829 [==============================] - 1s 168us/step - loss: 2.1292 - accuracy: 0.3043 - val_loss: 2.5142 - val_accuracy: 0.2359
#
# Epoch 00035: loss improved from 2.16879 to 2.12921, saving model to cnn_best_model.h5
# Epoch 36/50
# 3829/3829 [==============================] - 1s 166us/step - loss: 2.1232 - accuracy: 0.3147 - val_loss: 2.5158 - val_accuracy: 0.2380
#
# Epoch 00036: loss improved from 2.12921 to 2.12320, saving model to cnn_best_model.h5
# Epoch 37/50
# 3829/3829 [==============================] - 1s 214us/step - loss: 2.1106 - accuracy: 0.3186 - val_loss: 2.5027 - val_accuracy: 0.2422
#
# Epoch 00037: loss improved from 2.12320 to 2.11060, saving model to cnn_best_model.h5
# Epoch 38/50
# 3829/3829 [==============================] - 1s 226us/step - loss: 2.0963 - accuracy: 0.3207 - val_loss: 2.5161 - val_accuracy: 0.2203
#
# Epoch 00038: loss improved from 2.11060 to 2.09629, saving model to cnn_best_model.h5
# Epoch 39/50
# 3829/3829 [==============================] - 1s 171us/step - loss: 2.0720 - accuracy: 0.3278 - val_loss: 2.4887 - val_accuracy: 0.2463
#
# Epoch 00039: loss improved from 2.09629 to 2.07195, saving model to cnn_best_model.h5
# Epoch 40/50
# 3829/3829 [==============================] - 1s 181us/step - loss: 2.0473 - accuracy: 0.3309 - val_loss: 2.5138 - val_accuracy: 0.2223
#
# Epoch 00040: loss improved from 2.07195 to 2.04734, saving model to cnn_best_model.h5
# Epoch 41/50
# 3829/3829 [==============================] - 1s 182us/step - loss: 2.0136 - accuracy: 0.3335 - val_loss: 2.5124 - val_accuracy: 0.2317
#
# Epoch 00041: loss improved from 2.04734 to 2.01360, saving model to cnn_best_model.h5
# Epoch 42/50
# 3829/3829 [==============================] - 1s 173us/step - loss: 2.0114 - accuracy: 0.3507 - val_loss: 2.5128 - val_accuracy: 0.2255
#
# Epoch 00042: loss improved from 2.01360 to 2.01135, saving model to cnn_best_model.h5
# Epoch 43/50
# 3829/3829 [==============================] - 1s 170us/step - loss: 1.9771 - accuracy: 0.3612 - val_loss: 2.5121 - val_accuracy: 0.2265
#
# Epoch 00043: loss improved from 2.01135 to 1.97708, saving model to cnn_best_model.h5
# Epoch 44/50
# 3829/3829 [==============================] - 1s 156us/step - loss: 1.9595 - accuracy: 0.3622 - val_loss: 2.5264 - val_accuracy: 0.2161
#
# Epoch 00044: loss improved from 1.97708 to 1.95955, saving model to cnn_best_model.h5
# Epoch 45/50
# 3829/3829 [==============================] - 1s 168us/step - loss: 1.9527 - accuracy: 0.3557 - val_loss: 2.5074 - val_accuracy: 0.2307
#
# Epoch 00045: loss improved from 1.95955 to 1.95266, saving model to cnn_best_model.h5
# Epoch 46/50
# 3829/3829 [==============================] - 1s 173us/step - loss: 1.9352 - accuracy: 0.3568 - val_loss: 2.5517 - val_accuracy: 0.2265
#
# Epoch 00046: loss improved from 1.95266 to 1.93516, saving model to cnn_best_model.h5
# Epoch 47/50
# 3829/3829 [==============================] - 1s 169us/step - loss: 1.9105 - accuracy: 0.3669 - val_loss: 2.5241 - val_accuracy: 0.2265
#
# Epoch 00047: loss improved from 1.93516 to 1.91049, saving model to cnn_best_model.h5
# Epoch 48/50
# 3829/3829 [==============================] - 1s 158us/step - loss: 1.8906 - accuracy: 0.3797 - val_loss: 2.5633 - val_accuracy: 0.2035
#
# Epoch 00048: loss improved from 1.91049 to 1.89062, saving model to cnn_best_model.h5
# Epoch 49/50
# 3829/3829 [==============================] - 1s 174us/step - loss: 1.8735 - accuracy: 0.3716 - val_loss: 2.5532 - val_accuracy: 0.2025
#
# Epoch 00049: loss improved from 1.89062 to 1.87351, saving model to cnn_best_model.h5
# Epoch 50/50
# 3829/3829 [==============================] - 1s 174us/step - loss: 1.8636 - accuracy: 0.3810 - val_loss: 2.5508 - val_accuracy: 0.2161
#
# Epoch 00050: loss improved from 1.87351 to 1.86361, saving model to cnn_best_model.h5

# %% [markdown]
# ### Loading best LSTM model to predict new chords

# %%
model = load_model('lstm_best_model.h5')

start = np.random.randint(0, len(x_val)-1)
random_start_sequence = x_val[start]

output_dir_lstm = 'lstm_output'
music = generate_music(model, notes_dictionary, lookback, random_start_sequence)
convert_to_midi(music,output_dir_lstm)

# %% [markdown]
# ### Loading best 1DCNN model to predict new chords

# %%
model = load_model('cnn_best_model.h5')

start = np.random.randint(0, len(x_val)-1)
random_start_sequence = x_val[start]

output_dir_cnn = 'cnn_output'
music = generate_music(model, notes_dictionary, lookback, random_start_sequence)
convert_to_midi(music,output_dir_cnn)

# %% [markdown]
# ### Training loss for both the deep learning models

# %%
plt.plot(lstm_history.history['loss'],label='LSTM')
plt.plot(cnn_history.history['loss'],label='1DCNN')
plt.xlabel('Epochs')
plt.ylabel('Training Loss')
plt.legend()
plt.show()

# %% [markdown]
# ### Test set accuracy for both the deep learning models

# %%
plt.plot(lstm_history.history['val_accuracy'],label='LSTM')
plt.plot(cnn_history.history['val_accuracy'],label='1DCNN')
plt.xlabel('Epochs')
plt.ylabel('Test set accuracy')
plt.legend()
plt.show()
